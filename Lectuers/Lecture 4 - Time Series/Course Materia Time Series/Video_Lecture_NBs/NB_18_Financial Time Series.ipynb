# %% [markdown]
# # Part 4: Managing Time Series Data With Pandas

# %% [markdown]
# ## Time Series Advanced / Financial Data

# %% [markdown]
# ### Importing and Exporting Stock Price Data from Yahoo Finance

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
ticker = ["AAPL", "BA", "KO", "IBM", "DIS", "MSFT" ]
ticker2 = ["AAPL", "BA", "KO", "IBM", "DIS", "MSFT",'TSLA','GOOG']

# %%
stocks = yf.download(ticker, start = "2010-01-01", end = "2024-02-06")
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
stocks2 = yf.download(ticker2, start = "2010-01-01", end = "2024-04-4")
# Out:
# [*********************100%%**********************]  8 of 8 completed

# %%
stocks2.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'BA'),
#             ('Adj Close',  'DIS'),
#             ('Adj Close', 'GOOG'),
#             ('Adj Close',  'IBM'),
#             ('Adj Close',   'KO'),
#             ('Adj Close', 'MSFT'),
#             ('Adj Close', 'TSLA'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'BA'),
#             (    'Close',  'DIS'),
#             (    'Close', 'GOOG'),
#             (    'Close',  'IBM'),
#             (    'Close',   'KO'),
#             (    'Close', 'MSFT'),
#             (    'Close', 'TSLA'),
#             (     'High', 'AAPL'),
#             (     'High',   'BA'),
#             (     'High',  'DIS'),
#             (     'High', 'GOOG'),
#             (     'High',  'IBM'),
#             (     'High',   'KO'),
#             (     'High', 'MSFT'),
#             (     'High', 'TSLA'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'BA'),
#             (      'Low',  'DIS'),
#             (      'Low', 'GOOG'),
#             (      'Low',  'IBM'),
#             (      'Low',   'KO'),
#             (      'Low', 'MSFT'),
#             (      'Low', 'TSLA'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'BA'),
#             (     'Open',  'DIS'),
#             (     'Open', 'GOOG'),
#             (     'Open',  'IBM'),
#             (     'Open',   'KO'),
#             (     'Open', 'MSFT'),
#             (     'Open', 'TSLA'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'BA'),
#             (   'Volume',  'DIS'),
#             (   'Volume', 'GOOG'),
#             (   'Volume',  'IBM'),
#             (   'Volume',   'KO'),
#             (   'Volume', 'MSFT'),
#             (   'Volume', 'TSLA')],
#            names=['Price', 'Ticker'])

# %%
stocks.tail()
# Out:
# Price        Adj Close                                                \
# Ticker            AAPL          BA        DIS         IBM         KO
# Date
# 2024-01-30  187.545975  200.440002  96.940002  184.342743  59.424683
# 2024-01-31  183.915543  211.039993  96.050003  180.211777  59.017937
# 2024-02-01  186.369095  209.809998  97.059998  183.390945  60.496109
# 2024-02-02  185.361740  209.380005  97.129997  182.301788  60.059601
# 2024-02-05  187.186920  206.630005  96.650002  179.976288  59.563568
#
# Price                        Close                                     ...  \
# Ticker            MSFT        AAPL          BA        DIS         IBM  ...
# Date                                                                   ...
# 2024-01-30  407.101501  188.039993  200.440002  96.940002  187.869995  ...
# 2024-01-31  396.131622  184.399994  211.039993  96.050003  183.660004  ...
# 2024-02-01  402.309052  186.860001  209.809998  97.059998  186.899994  ...
# 2024-02-02  409.721954  185.850006  209.380005  97.129997  185.789993  ...
# 2024-02-05  404.172241  187.679993  206.630005  96.650002  183.419998  ...
#
# Price            Open                                        Volume            \
# Ticker            DIS         IBM         KO        MSFT       AAPL        BA
# Date
# 2024-01-30  96.519997  187.710007  59.849998  412.260010   55859400  13321200
# 2024-01-31  96.419998  187.050003  60.099998  406.959991   55467800  22409400
# 2024-02-01  96.370003  183.630005  59.570000  401.829987   64885400  10679200
# 2024-02-02  96.279999  187.100006  60.820000  403.809998  102518000   6271200
# 2024-02-05  96.699997  185.509995  60.380001  409.899994   69668800   8682500
#
# Price
# Ticker           DIS      IBM        KO      MSFT
# Date
# 2024-01-30   9139600  4575100  22061500  33477600
# 2024-01-31   9592300  8876100  22837000  47871100
# 2024-02-01   8484800  4669400  15870900  30657700
# 2024-02-02   9319100  4054200  17543500  28245000
# 2024-02-05  11679300  4379600  12759600  25352300
#
# [5 rows x 36 columns]

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3546 entries, 2010-01-04 to 2024-02-05
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  3546 non-null   float64
#  1   (Adj Close, BA)    3546 non-null   float64
#  2   (Adj Close, DIS)   3546 non-null   float64
#  3   (Adj Close, IBM)   3546 non-null   float64
#  4   (Adj Close, KO)    3546 non-null   float64
#  5   (Adj Close, MSFT)  3546 non-null   float64
#  6   (Close, AAPL)      3546 non-null   float64
#  7   (Close, BA)        3546 non-null   float64
#  8   (Close, DIS)       3546 non-null   float64
#  9   (Close, IBM)       3546 non-null   float64
#  10  (Close, KO)        3546 non-null   float64
#  11  (Close, MSFT)      3546 non-null   float64
#  12  (High, AAPL)       3546 non-null   float64
#  13  (High, BA)         3546 non-null   float64
#  14  (High, DIS)        3546 non-null   float64
#  15  (High, IBM)        3546 non-null   float64
#  16  (High, KO)         3546 non-null   float64
#  17  (High, MSFT)       3546 non-null   float64
#  18  (Low, AAPL)        3546 non-null   float64
#  19  (Low, BA)          3546 non-null   float64
#  20  (Low, DIS)         3546 non-null   float64
#  21  (Low, IBM)         3546 non-null   float64
#  22  (Low, KO)          3546 non-null   float64
#  23  (Low, MSFT)        3546 non-null   float64
#  24  (Open, AAPL)       3546 non-null   float64
#  25  (Open, BA)         3546 non-null   float64
#  26  (Open, DIS)        3546 non-null   float64
#  27  (Open, IBM)        3546 non-null   float64
#  28  (Open, KO)         3546 non-null   float64
#  29  (Open, MSFT)       3546 non-null   float64
#  30  (Volume, AAPL)     3546 non-null   int64
#  31  (Volume, BA)       3546 non-null   int64
#  32  (Volume, DIS)      3546 non-null   int64
#  33  (Volume, IBM)      3546 non-null   int64
#  34  (Volume, KO)       3546 non-null   int64
#  35  (Volume, MSFT)     3546 non-null   int64
# dtypes: float64(30), int64(6)
# memory usage: 1.0 MB

# %%
stocks.to_csv("stocks.csv")

# %%
stocks = pd.read_csv("stocks.csv", header = [0, 1], index_col = [0], parse_dates = [0])

# %%
stocks.head()
# Out:
# Price      Adj Close                                                         \
# Ticker          AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2010-01-04  6.461977  43.777554  27.843176  76.012863  18.351236  23.389397
# 2010-01-05  6.473148  45.211334  27.773722  75.094612  18.129240  23.396961
# 2010-01-06  6.370185  46.582809  27.626127  74.606789  18.122810  23.253368
# 2010-01-07  6.358408  48.468559  27.634809  74.348541  18.077768  23.011547
# 2010-01-08  6.400681  48.000999  27.678217  75.094612  17.743162  23.170240
#
# Price          Close                                    ...   Open  \
# Ticker          AAPL         BA        DIS         IBM  ...    DIS
# Date                                                    ...
# 2010-01-04  7.643214  56.180000  32.070000  126.625237  ...  32.50
# 2010-01-05  7.656429  58.020000  31.990000  125.095604  ...  32.07
# 2010-01-06  7.534643  59.779999  31.820000  124.282982  ...  31.90
# 2010-01-07  7.520714  62.200001  31.830000  123.852776  ...  31.77
# 2010-01-08  7.570714  61.599998  31.879999  125.095604  ...  31.66
#
# Price                                            Volume                      \
# Ticker             IBM         KO       MSFT       AAPL        BA       DIS
# Date
# 2010-01-04  125.411087  28.580000  30.620001  493729600   6186700  13700400
# 2010-01-05  125.889099  28.424999  30.850000  601904800   8867800  10307700
# 2010-01-06  124.933075  28.174999  30.879999  552160000   8836500  10709500
# 2010-01-07  124.158699  28.165001  30.629999  477131200  14379100   8202100
# 2010-01-08  123.393883  27.730000  30.280001  447610800   7146600   7657500
#
# Price
# Ticker          IBM        KO      MSFT
# Date
# 2010-01-04  6438444  13870400  38409100
# 2010-01-05  7156104  23172400  49749600
# 2010-01-06  5863144  19264600  58182400
# 2010-01-07  6109268  13234600  50559700
# 2010-01-08  4390271  28712400  51197400
#
# [5 rows x 36 columns]

# %%
stocks.columns = stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'BA'),  ('Adj Close', 'DIS'),
#         ('Adj Close', 'IBM'),   ('Adj Close', 'KO'), ('Adj Close', 'MSFT'),
#            ('Close', 'AAPL'),       ('Close', 'BA'),      ('Close', 'DIS'),
#             ('Close', 'IBM'),       ('Close', 'KO'),     ('Close', 'MSFT'),
#             ('High', 'AAPL'),        ('High', 'BA'),       ('High', 'DIS'),
#              ('High', 'IBM'),        ('High', 'KO'),      ('High', 'MSFT'),
#              ('Low', 'AAPL'),         ('Low', 'BA'),        ('Low', 'DIS'),
#               ('Low', 'IBM'),         ('Low', 'KO'),       ('Low', 'MSFT'),
#             ('Open', 'AAPL'),        ('Open', 'BA'),       ('Open', 'DIS'),
#              ('Open', 'IBM'),        ('Open', 'KO'),      ('Open', 'MSFT'),
#           ('Volume', 'AAPL'),      ('Volume', 'BA'),     ('Volume', 'DIS'),
#            ('Volume', 'IBM'),      ('Volume', 'KO'),    ('Volume', 'MSFT')],
#       dtype='object')

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)

# %%
stocks.head()
# Out:
#            Adj Close                                                         \
#                 AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2010-01-04  6.461977  43.777554  27.843176  76.012863  18.351236  23.389397
# 2010-01-05  6.473148  45.211334  27.773722  75.094612  18.129240  23.396961
# 2010-01-06  6.370185  46.582809  27.626127  74.606789  18.122810  23.253368
# 2010-01-07  6.358408  48.468559  27.634809  74.348541  18.077768  23.011547
# 2010-01-08  6.400681  48.000999  27.678217  75.094612  17.743162  23.170240
#
#                Close                                    ...   Open  \
#                 AAPL         BA        DIS         IBM  ...    DIS
# Date                                                    ...
# 2010-01-04  7.643214  56.180000  32.070000  126.625237  ...  32.50
# 2010-01-05  7.656429  58.020000  31.990000  125.095604  ...  32.07
# 2010-01-06  7.534643  59.779999  31.820000  124.282982  ...  31.90
# 2010-01-07  7.520714  62.200001  31.830000  123.852776  ...  31.77
# 2010-01-08  7.570714  61.599998  31.879999  125.095604  ...  31.66
#
#                                                  Volume                      \
#                    IBM         KO       MSFT       AAPL        BA       DIS
# Date
# 2010-01-04  125.411087  28.580000  30.620001  493729600   6186700  13700400
# 2010-01-05  125.889099  28.424999  30.850000  601904800   8867800  10307700
# 2010-01-06  124.933075  28.174999  30.879999  552160000   8836500  10709500
# 2010-01-07  124.158699  28.165001  30.629999  477131200  14379100   8202100
# 2010-01-08  123.393883  27.730000  30.280001  447610800   7146600   7657500
#
#
#                 IBM        KO      MSFT
# Date
# 2010-01-04  6438444  13870400  38409100
# 2010-01-05  7156104  23172400  49749600
# 2010-01-06  5863144  19264600  58182400
# 2010-01-07  6109268  13234600  50559700
# 2010-01-08  4390271  28712400  51197400
#
# [5 rows x 36 columns]

# %%
stocks.swaplevel(axis = 1).sort_index(axis = 1)
# Out:
#                  AAPL                                                         \
#             Adj Close      Close       High        Low       Open     Volume
# Date
# 2009-12-31   6.444382   7.526071   7.619643   7.520000   7.611786  352410800
# 2010-01-04   6.544689   7.643214   7.660714   7.585000   7.622500  493729600
# 2010-01-05   6.556003   7.656429   7.699643   7.616071   7.664286  601904800
# 2010-01-06   6.451722   7.534643   7.686786   7.526786   7.656429  552160000
# 2010-01-07   6.439795   7.520714   7.571429   7.466071   7.562500  477131200
# ...               ...        ...        ...        ...        ...        ...
# 2019-01-30  40.054211  41.312500  41.537498  40.057499  40.812500  244439200
# 2019-01-31  40.342648  41.610001  42.250000  41.139999  41.527500  162958400
# 2019-02-01  40.362049  41.630001  42.244999  41.482498  41.740002  130672400
# 2019-02-04  41.508526  42.812500  42.915001  41.820000  41.852501  125982000
# 2019-02-05  42.218712  43.544998  43.770000  43.087502  43.215000  144406400
#
#                     BA                                      ...         KO  \
#              Adj Close       Close        High         Low  ...       High
# Date                                                        ...
# 2009-12-31   42.180111   54.130001   55.220001   54.049999  ...  28.875000
# 2010-01-04   43.777550   56.180000   56.389999   54.799999  ...  28.610001
# 2010-01-05   45.211342   58.020000   58.279999   56.000000  ...  28.495001
# 2010-01-06   46.582806   59.779999   59.990002   57.880001  ...  28.219999
# 2010-01-07   48.468559   62.200001   62.310001   59.020000  ...  28.184999
# ...                ...         ...         ...         ...  ...        ...
# 2019-01-30  376.746277  387.720001  391.970001  380.500000  ...  47.889999
# 2019-01-31  374.705719  385.619995  388.989990  382.079987  ...  48.779999
# 2019-02-01  376.464478  387.429993  392.799988  384.730011  ...  48.779999
# 2019-02-04  385.763641  397.000000  397.070007  388.119995  ...  49.450001
# 2019-02-05  398.570618  410.179993  410.750000  399.549988  ...  49.470001
#
#                                                   MSFT              \
#                   Low       Open    Volume   Adj Close       Close
# Date
# 2009-12-31  28.465000  28.790001  10848800   23.493391   30.480000
# 2010-01-04  28.450001  28.580000  13870400   23.855658   30.950001
# 2010-01-05  28.070000  28.424999  23172400   23.863363   30.959999
# 2010-01-06  27.990000  28.174999  19264600   23.716921   30.770000
# 2010-01-07  27.875000  28.165001  13234600   23.470272   30.450001
# ...               ...        ...       ...         ...         ...
# 2019-01-30  47.189999  47.250000  12952500  102.656555  106.379997
# 2019-01-31  47.470001  47.849998  32181500  100.774811  104.430000
# 2019-02-01  48.400002  48.480000  19130100   99.182549  102.779999
# 2019-02-04  48.540001  48.700001  15105700  102.038956  105.739998
# 2019-02-05  49.099998  49.330002  12651900  103.467155  107.220001
#
#
#                   High         Low        Open    Volume
# Date
# 2009-12-31   30.990000   30.480000   30.980000  31929700
# 2010-01-04   31.100000   30.590000   30.620001  38409100
# 2010-01-05   31.100000   30.639999   30.850000  49749600
# 2010-01-06   31.080000   30.520000   30.879999  58182400
# 2010-01-07   30.700001   30.190001   30.629999  50559700
# ...                ...         ...         ...       ...
# 2019-01-30  106.379997  104.330002  104.620003  49471900
# 2019-01-31  105.220001  103.180000  103.800003  55636400
# 2019-02-01  104.099998  102.349998  103.779999  35535700
# 2019-02-04  105.800003  102.769997  102.870003  31315100
# 2019-02-05  107.269997  105.959999  106.059998  27325400
#
# [2289 rows x 36 columns]

# %% [markdown]
# ### Initial Inspection and Visualization

# %%
import pandas as pd

# %%
stocks = pd.read_csv("stocks.csv", header = [0,1], index_col= [0], parse_dates= [0])

# %%
stocks.head()
# Out:
# Price      Adj Close                                                         \
# Ticker          AAPL         BA        DIS        IBM         KO       MSFT
# Date
# 2010-01-04  6.461977  43.777554  27.843176  76.012863  18.351236  23.389397
# 2010-01-05  6.473148  45.211334  27.773722  75.094612  18.129240  23.396961
# 2010-01-06  6.370185  46.582809  27.626127  74.606789  18.122810  23.253368
# 2010-01-07  6.358408  48.468559  27.634809  74.348541  18.077768  23.011547
# 2010-01-08  6.400681  48.000999  27.678217  75.094612  17.743162  23.170240
#
# Price          Close                                    ...   Open  \
# Ticker          AAPL         BA        DIS         IBM  ...    DIS
# Date                                                    ...
# 2010-01-04  7.643214  56.180000  32.070000  126.625237  ...  32.50
# 2010-01-05  7.656429  58.020000  31.990000  125.095604  ...  32.07
# 2010-01-06  7.534643  59.779999  31.820000  124.282982  ...  31.90
# 2010-01-07  7.520714  62.200001  31.830000  123.852776  ...  31.77
# 2010-01-08  7.570714  61.599998  31.879999  125.095604  ...  31.66
#
# Price                                            Volume                      \
# Ticker             IBM         KO       MSFT       AAPL        BA       DIS
# Date
# 2010-01-04  125.411087  28.580000  30.620001  493729600   6186700  13700400
# 2010-01-05  125.889099  28.424999  30.850000  601904800   8867800  10307700
# 2010-01-06  124.933075  28.174999  30.879999  552160000   8836500  10709500
# 2010-01-07  124.158699  28.165001  30.629999  477131200  14379100   8202100
# 2010-01-08  123.393883  27.730000  30.280001  447610800   7146600   7657500
#
# Price
# Ticker          IBM        KO      MSFT
# Date
# 2010-01-04  6438444  13870400  38409100
# 2010-01-05  7156104  23172400  49749600
# 2010-01-06  5863144  19264600  58182400
# 2010-01-07  6109268  13234600  50559700
# 2010-01-08  4390271  28712400  51197400
#
# [5 rows x 36 columns]

# %%
stocks.tail()
# Out:
# Price        Adj Close                                                \
# Ticker            AAPL          BA        DIS         IBM         KO
# Date
# 2024-01-30  187.545975  200.440002  96.940002  184.342743  59.424683
# 2024-01-31  183.915543  211.039993  96.050003  180.211777  59.017937
# 2024-02-01  186.369095  209.809998  97.059998  183.390945  60.496109
# 2024-02-02  185.361740  209.380005  97.129997  182.301788  60.059601
# 2024-02-05  187.186920  206.630005  96.650002  179.976288  59.563568
#
# Price                        Close                                     ...  \
# Ticker            MSFT        AAPL          BA        DIS         IBM  ...
# Date                                                                   ...
# 2024-01-30  407.101501  188.039993  200.440002  96.940002  187.869995  ...
# 2024-01-31  396.131622  184.399994  211.039993  96.050003  183.660004  ...
# 2024-02-01  402.309052  186.860001  209.809998  97.059998  186.899994  ...
# 2024-02-02  409.721954  185.850006  209.380005  97.129997  185.789993  ...
# 2024-02-05  404.172241  187.679993  206.630005  96.650002  183.419998  ...
#
# Price            Open                                        Volume            \
# Ticker            DIS         IBM         KO        MSFT       AAPL        BA
# Date
# 2024-01-30  96.519997  187.710007  59.849998  412.260010   55859400  13321200
# 2024-01-31  96.419998  187.050003  60.099998  406.959991   55467800  22409400
# 2024-02-01  96.370003  183.630005  59.570000  401.829987   64885400  10679200
# 2024-02-02  96.279999  187.100006  60.820000  403.809998  102518000   6271200
# 2024-02-05  96.699997  185.509995  60.380001  409.899994   69668800   8682500
#
# Price
# Ticker           DIS      IBM        KO      MSFT
# Date
# 2024-01-30   9139600  4575100  22061500  33477600
# 2024-01-31   9592300  8876100  22837000  47871100
# 2024-02-01   8484800  4669400  15870900  30657700
# 2024-02-02   9319100  4054200  17543500  28245000
# 2024-02-05  11679300  4379600  12759600  25352300
#
# [5 rows x 36 columns]

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3546 entries, 2010-01-04 to 2024-02-05
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  3546 non-null   float64
#  1   (Adj Close, BA)    3546 non-null   float64
#  2   (Adj Close, DIS)   3546 non-null   float64
#  3   (Adj Close, IBM)   3546 non-null   float64
#  4   (Adj Close, KO)    3546 non-null   float64
#  5   (Adj Close, MSFT)  3546 non-null   float64
#  6   (Close, AAPL)      3546 non-null   float64
#  7   (Close, BA)        3546 non-null   float64
#  8   (Close, DIS)       3546 non-null   float64
#  9   (Close, IBM)       3546 non-null   float64
#  10  (Close, KO)        3546 non-null   float64
#  11  (Close, MSFT)      3546 non-null   float64
#  12  (High, AAPL)       3546 non-null   float64
#  13  (High, BA)         3546 non-null   float64
#  14  (High, DIS)        3546 non-null   float64
#  15  (High, IBM)        3546 non-null   float64
#  16  (High, KO)         3546 non-null   float64
#  17  (High, MSFT)       3546 non-null   float64
#  18  (Low, AAPL)        3546 non-null   float64
#  19  (Low, BA)          3546 non-null   float64
#  20  (Low, DIS)         3546 non-null   float64
#  21  (Low, IBM)         3546 non-null   float64
#  22  (Low, KO)          3546 non-null   float64
#  23  (Low, MSFT)        3546 non-null   float64
#  24  (Open, AAPL)       3546 non-null   float64
#  25  (Open, BA)         3546 non-null   float64
#  26  (Open, DIS)        3546 non-null   float64
#  27  (Open, IBM)        3546 non-null   float64
#  28  (Open, KO)         3546 non-null   float64
#  29  (Open, MSFT)       3546 non-null   float64
#  30  (Volume, AAPL)     3546 non-null   int64
#  31  (Volume, BA)       3546 non-null   int64
#  32  (Volume, DIS)      3546 non-null   int64
#  33  (Volume, IBM)      3546 non-null   int64
#  34  (Volume, KO)       3546 non-null   int64
#  35  (Volume, MSFT)     3546 non-null   int64
# dtypes: float64(30), int64(6)
# memory usage: 1.0 MB

# %%
stocks.describe()
# Out:
# Price     Adj Close                                                      \
# Ticker         AAPL           BA          DIS          IBM           KO
# count   3546.000000  3546.000000  3546.000000  3546.000000  3546.000000
# mean      58.643632   165.336613    91.156639   108.167881    37.128792
# std       56.522955    96.020623    40.372629    15.886269    12.323819
# min        5.798901    43.777554    25.453194    70.239418    16.243885
# 25%       17.063963    88.337687    58.321414    99.674473    27.974673
# 50%       29.396989   134.586449    94.860420   107.643139    34.658550
# 75%       94.945303   219.407501   110.004992   117.925280    46.563401
# max      197.589523   430.299988   201.254089   186.854675    62.319370
#
# Price                      Close                                         ...  \
# Ticker         MSFT         AAPL           BA          DIS          IBM  ...
# count   3546.000000  3546.000000  3546.000000  3546.000000  3546.000000  ...
# mean     111.481700    60.790403   174.708184    94.706762   147.974520  ...
# std      104.506913    56.240759    93.499933    39.060017    23.466663  ...
# min       17.549156     6.858929    56.180000    29.000000    90.602295  ...
# 25%       27.504719    19.724376   103.319998    64.362499   129.878109  ...
# 50%       57.594671    32.571249   147.320000    98.689999   142.419365  ...
# 75%      197.341270    97.218750   219.407501   113.040001   164.694069  ...
# max      409.721954   198.110001   440.619995   201.910004   206.309753  ...
#
# Price          Open                                               Volume  \
# Ticker          DIS          IBM           KO         MSFT          AAPL
# count   3546.000000  3546.000000  3546.000000  3546.000000  3.546000e+03
# mean      94.736918   147.923849    45.100501   117.120663  2.410452e+08
# std       39.124390    23.447225     9.532313   103.955907  2.202250e+08
# min       28.730000    90.439774    25.110001    23.090000  2.404830e+07
# 25%       64.330000   129.887672    38.957500    33.110000  9.160480e+07
# 50%       98.674999   142.490440    43.580002    63.325001  1.509699e+08
# 75%      113.180000   164.419456    52.779999   204.867500  3.262483e+08
# max      200.190002   205.908218    67.000000   412.260010  1.880998e+09
#
# Price
# Ticker            BA           DIS           IBM            KO          MSFT
# count   3.546000e+03  3.546000e+03  3.546000e+03  3.546000e+03  3.546000e+03
# mean    7.338287e+06  1.000944e+07  5.001238e+06  1.505486e+07  3.719835e+07
# std     8.662418e+06  6.274545e+06  2.803178e+06  6.696818e+06  2.101238e+07
# min     7.889000e+05  2.165700e+06  1.247878e+06  2.996300e+06  7.425600e+06
# 25%     3.466525e+06  6.546300e+06  3.428422e+06  1.086472e+07  2.348488e+07
# 50%     4.751000e+06  8.397150e+06  4.306510e+06  1.360965e+07  3.134205e+07
# 75%     7.434075e+06  1.136570e+07  5.615844e+06  1.740215e+07  4.567298e+07
# max     1.032128e+08  8.741070e+07  3.981442e+07  9.896750e+07  3.193179e+08
#
# [8 rows x 36 columns]

# %%
close = stocks.loc[:, "Close"].copy()

# %%
close.head(10)
# Out:
# Ticker           AAPL          BA         DIS       GOOG         IBM  \
# Date
# 2019-01-02  39.480000  323.809998  108.970001  52.292500  110.143402
# 2019-01-03  35.547501  310.899994  106.330002  50.803001  107.944550
# 2019-01-04  37.064999  327.079987  109.610001  53.535500  112.160614
# 2019-01-07  36.982498  328.109985  110.559998  53.419498  112.954109
# 2019-01-08  37.687500  340.529999  111.419998  53.813999  114.560226
# 2019-01-09  38.327499  343.829987  112.669998  53.733002  115.382408
# 2019-01-10  38.450001  352.609985  112.800003  53.516499  116.434036
# 2019-01-11  38.072498  352.899994  112.650002  52.859501  116.118546
# 2019-01-14  37.500000  350.359985  112.419998  52.234501  115.095604
# 2019-01-15  38.267502  352.239990  111.760002  53.857498  116.376671
#
# Ticker             KO        MSFT       TSLA
# Date
# 2019-01-02  46.930000  101.120003  20.674667
# 2019-01-03  46.639999   97.400002  20.024000
# 2019-01-04  47.570000  101.930000  21.179333
# 2019-01-07  46.950001  102.059998  22.330667
# 2019-01-08  47.480000  102.800003  22.356667
# 2019-01-09  46.570000  104.269997  22.568666
# 2019-01-10  47.070000  103.599998  22.997999
# 2019-01-11  47.340000  102.800003  23.150667
# 2019-01-14  47.150002  102.050003  22.293333
# 2019-01-15  47.570000  105.010002  22.962000

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8-whitegrid")

# %%
close.plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.title("Stock prices", fontsize=20)
plt.show()

# %% [markdown]
# ### Normalizing Time Series to a Base Value (100)

# %%
close.head()
# Out:
# Ticker          AAPL         BA        DIS       GOOG         IBM         KO  \
# Date
# 2010-01-04  7.643214  56.180000  32.070000  15.610239  126.625237  28.520000
# 2010-01-05  7.656429  58.020000  31.990000  15.541497  125.095604  28.174999
# 2010-01-06  7.534643  59.779999  31.820000  15.149715  124.282982  28.165001
# 2010-01-07  7.520714  62.200001  31.830000  14.797037  123.852776  28.094999
# 2010-01-08  7.570714  61.599998  31.879999  14.994298  125.095604  27.575001
#
# Ticker           MSFT  TSLA
# Date
# 2010-01-04  30.950001   NaN
# 2010-01-05  30.959999   NaN
# 2010-01-06  30.770000   NaN
# 2010-01-07  30.450001   NaN
# 2010-01-08  30.660000   NaN

# %%
close.iloc[0,0]
# Out:
# 7.643214225769043

# %%
close.AAPL.div(close.iloc[0,0])#.mul(100)
# Out:
# Date
# 2010-01-04     1.000000
# 2010-01-05     1.001729
# 2010-01-06     0.985795
# 2010-01-07     0.983973
# 2010-01-08     0.990514
#                 ...
# 2024-03-27    22.675015
# 2024-03-28    22.435587
# 2024-04-01    22.245876
# 2024-04-02    22.090182
# 2024-04-03    22.196158
# Name: AAPL, Length: 3586, dtype: float64

# %%
close.iloc[0]
# Out:
# Ticker
# AAPL      7.643214
# BA       56.180000
# DIS      32.070000
# GOOG     15.610239
# IBM     126.625237
# KO       28.520000
# MSFT     30.950001
# TSLA           NaN
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
norm = close.div(close.iloc[0]).mul(100)
norm
# Out:
# Ticker             AAPL          BA         DIS         GOOG         IBM  \
# Date
# 2010-01-04   100.000000  100.000000  100.000000   100.000000  100.000000
# 2010-01-05   100.172893  103.275187   99.750546    99.559636   98.792000
# 2010-01-06    98.579511  106.407972   99.220455    97.049862   98.150247
# 2010-01-07    98.397266  110.715558   99.251638    94.790586   97.810499
# 2010-01-08    99.051443  109.647558   99.407544    96.054250   98.792000
# ...                 ...         ...         ...          ...         ...
# 2024-03-27  2267.501504  341.669626  377.237307   973.335528  150.680866
# 2024-03-28  2243.558674  343.520834  381.540386   975.385414  150.807226
# 2024-04-01  2224.587638  337.308649  378.952292  1002.547108  149.914825
# 2024-04-02  2209.018240  334.709847  382.974745   998.511264  149.164582
# 2024-04-03  2219.615843  329.156278  371.000949  1001.714290  150.759832
#
# Ticker              KO         MSFT  TSLA
# Date
# 2010-01-04  100.000000   100.000000   NaN
# 2010-01-05   98.790318   100.032305   NaN
# 2010-01-06   98.755261    99.418416   NaN
# 2010-01-07   98.509814    98.384491   NaN
# 2010-01-08   96.686537    99.063002   NaN
# ...                ...          ...   ...
# 2024-03-27  213.990175  1361.647762   NaN
# 2024-03-28  214.516127  1359.353767   NaN
# 2024-04-01  212.762971  1371.793205   NaN
# 2024-04-02  210.904630  1361.680104   NaN
# 2024-04-03  209.782612  1358.481428   NaN
#
# [3586 rows x 8 columns]

# %%
norm.plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# ### The shift() method

# %%
close.head()
# Out:
# Ticker          AAPL         BA        DIS       GOOG         IBM         KO  \
# Date
# 2010-01-04  7.643214  56.180000  32.070000  15.610239  126.625237  28.520000
# 2010-01-05  7.656429  58.020000  31.990000  15.541497  125.095604  28.174999
# 2010-01-06  7.534643  59.779999  31.820000  15.149715  124.282982  28.165001
# 2010-01-07  7.520714  62.200001  31.830000  14.797037  123.852776  28.094999
# 2010-01-08  7.570714  61.599998  31.879999  14.994298  125.095604  27.575001
#
# Ticker           MSFT  TSLA
# Date
# 2010-01-04  30.950001   NaN
# 2010-01-05  30.959999   NaN
# 2010-01-06  30.770000   NaN
# 2010-01-07  30.450001   NaN
# 2010-01-08  30.660000   NaN

# %%
aapl = close.AAPL.copy().to_frame()

# %%
aapl.head()
# Out:
#                 AAPL
# Date
# 2010-01-04  7.643214
# 2010-01-05  7.656429
# 2010-01-06  7.534643
# 2010-01-07  7.520714
# 2010-01-08  7.570714

# %%
aapl.shift(periods = 1)
# Out:
#                   AAPL
# Date
# 2010-01-04         NaN
# 2010-01-05    7.643214
# 2010-01-06    7.656429
# 2010-01-07    7.534643
# 2010-01-08    7.520714
# ...                ...
# 2024-03-27  169.710007
# 2024-03-28  173.309998
# 2024-04-01  171.479996
# 2024-04-02  170.029999
# 2024-04-03  168.839996
#
# [3586 rows x 1 columns]

# %%
aapl["lag1"] = aapl.shift(periods = 1)

# %%
aapl.head(10)
# Out:
#                 AAPL      lag1
# Date
# 2010-01-04  7.643214       NaN
# 2010-01-05  7.656429  7.643214
# 2010-01-06  7.534643  7.656429
# 2010-01-07  7.520714  7.534643
# 2010-01-08  7.570714  7.520714
# 2010-01-11  7.503929  7.570714
# 2010-01-12  7.418571  7.503929
# 2010-01-13  7.523214  7.418571
# 2010-01-14  7.479643  7.523214
# 2010-01-15  7.354643  7.479643

# %%
aapl.AAPL.sub(aapl.lag1).to_frame()
# Out:
#                    0
# Date
# 2010-01-04       NaN
# 2010-01-05  0.013215
# 2010-01-06 -0.121786
# 2010-01-07 -0.013929
# 2010-01-08  0.050000
# ...              ...
# 2024-03-27  3.599991
# 2024-03-28 -1.830002
# 2024-04-01 -1.449997
# 2024-04-02 -1.190002
# 2024-04-03  0.809998
#
# [3586 rows x 1 columns]

# %%
aapl["Diff"] = aapl.AAPL.sub(aapl.lag1)

# %%
aapl.head()
# Out:
#                 AAPL      lag1      Diff
# Date
# 2010-01-04  7.643214       NaN       NaN
# 2010-01-05  7.656429  7.643214  0.013215
# 2010-01-06  7.534643  7.656429 -0.121786
# 2010-01-07  7.520714  7.534643 -0.013929
# 2010-01-08  7.570714  7.520714  0.050000

# %%
aapl.AAPL.div(aapl.lag1).sub(1).mul(100)
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05    0.172893
# 2010-01-06   -1.590632
# 2010-01-07   -0.184871
# 2010-01-08    0.664833
#                 ...
# 2024-03-27    2.121260
# 2024-03-28   -1.055912
# 2024-04-01   -0.845578
# 2024-04-02   -0.699878
# 2024-04-03    0.479743
# Length: 3586, dtype: float64

# %%
aapl["pct_change"] = aapl.AAPL.div(aapl.lag1).sub(1).mul(100)
aapl
# Out:
#                   AAPL        lag1      Diff  pct_change
# Date
# 2010-01-04    7.643214         NaN       NaN         NaN
# 2010-01-05    7.656429    7.643214  0.013215    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929   -0.184871
# 2010-01-08    7.570714    7.520714  0.050000    0.664833
# ...                ...         ...       ...         ...
# 2024-03-27  173.309998  169.710007  3.599991    2.121260
# 2024-03-28  171.479996  173.309998 -1.830002   -1.055912
# 2024-04-01  170.029999  171.479996 -1.449997   -0.845578
# 2024-04-02  168.839996  170.029999 -1.190002   -0.699878
# 2024-04-03  169.649994  168.839996  0.809998    0.479743
#
# [3586 rows x 4 columns]

# %%
aapl['pct_change'].resample('W').mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### The methods diff() and pct_change()

# %%
aapl.head()
# Out:
#                 AAPL      lag1      Diff  pct_change
# Date
# 2010-01-04  7.643214       NaN       NaN         NaN
# 2010-01-05  7.656429  7.643214  0.013215    0.172893
# 2010-01-06  7.534643  7.656429 -0.121786   -1.590632
# 2010-01-07  7.520714  7.534643 -0.013929   -0.184871
# 2010-01-08  7.570714  7.520714  0.050000    0.664833

# %%
aapl.AAPL.diff(periods = 2)
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05         NaN
# 2010-01-06   -0.108571
# 2010-01-07   -0.135715
# 2010-01-08    0.036071
#                 ...
# 2024-03-27    2.459991
# 2024-03-28    1.769989
# 2024-04-01   -3.279999
# 2024-04-02   -2.639999
# 2024-04-03   -0.380005
# Name: AAPL, Length: 3586, dtype: float64

# %%
aapl["Diff2"] = aapl.AAPL.diff(periods = 1)

# %%
aapl.head(10)
# Out:
#                 AAPL      lag1      Diff  pct_change     Diff2
# Date
# 2010-01-04  7.643214       NaN       NaN         NaN       NaN
# 2010-01-05  7.656429  7.643214  0.013215    0.172893  0.013215
# 2010-01-06  7.534643  7.656429 -0.121786   -1.590632 -0.121786
# 2010-01-07  7.520714  7.534643 -0.013929   -0.184871 -0.013929
# 2010-01-08  7.570714  7.520714  0.050000    0.664833  0.050000
# 2010-01-11  7.503929  7.570714 -0.066785   -0.882147 -0.066785
# 2010-01-12  7.418571  7.503929 -0.085358   -1.137513 -0.085358
# 2010-01-13  7.523214  7.418571  0.104643    1.410553  0.104643
# 2010-01-14  7.479643  7.523214 -0.043571   -0.579154 -0.043571
# 2010-01-15  7.354643  7.479643 -0.125000   -1.671203 -0.125000

# %%
aapl.Diff.equals(aapl.Diff2)
# Out:
# True

# %%
aapl["pct_change2"] = aapl.AAPL.pct_change(periods = 1).mul(100)

# %%
aapl.head()
# Out:
#                 AAPL      lag1      Diff  pct_change     Diff2  pct_change2
# Date
# 2010-01-04  7.643214       NaN       NaN         NaN       NaN          NaN
# 2010-01-05  7.656429  7.643214  0.013215    0.172893  0.013215     0.172893
# 2010-01-06  7.534643  7.656429 -0.121786   -1.590632 -0.121786    -1.590632
# 2010-01-07  7.520714  7.534643 -0.013929   -0.184871 -0.013929    -0.184871
# 2010-01-08  7.570714  7.520714  0.050000    0.664833  0.050000     0.664833

# %%
aapl.AAPL.resample("BM").last().pct_change(periods =1).mul(100).plot(color='red')
aapl.AAPL.resample("BM").first().pct_change(periods = 1).mul(100).plot()
plt.legend(["last","first"])
# Out:
# C:\Users\brhva\AppData\Local\Temp\ipykernel_28956\1580114163.py:1: FutureWarning: 'BM' is deprecated and will be removed in a future version, please use 'BME' instead.
#   aapl.AAPL.resample("BM").last().pct_change(periods =1).mul(100).plot(color='red')
# C:\Users\brhva\AppData\Local\Temp\ipykernel_28956\1580114163.py:2: FutureWarning: 'BM' is deprecated and will be removed in a future version, please use 'BME' instead.
#   aapl.AAPL.resample("BM").first().pct_change(periods = 1).mul(100).plot()

# %% [markdown]
# ### Measuring Stock Perfromance with MEAN Return and STD of Returns

# %%
import numpy as np

# %%
aapl = close.AAPL.copy().to_frame()

# %%
aapl.head()
# Out:
#                 AAPL
# Date
# 2010-01-04  7.643214
# 2010-01-05  7.656429
# 2010-01-06  7.534643
# 2010-01-07  7.520714
# 2010-01-08  7.570714

# %%
aapl.pct_change().dropna()
# Out:
#                 AAPL
# Date
# 2010-01-05  0.001729
# 2010-01-06 -0.015906
# 2010-01-07 -0.001849
# 2010-01-08  0.006648
# 2010-01-11 -0.008821
# ...              ...
# 2024-03-27  0.021213
# 2024-03-28 -0.010559
# 2024-04-01 -0.008456
# 2024-04-02 -0.006999
# 2024-04-03  0.004797
#
# [3585 rows x 1 columns]

# %%
ret = aapl.pct_change().mul(100).dropna()
ret.head()
# Out:
#                 AAPL
# Date
# 2010-01-05  0.172893
# 2010-01-06 -1.590632
# 2010-01-07 -0.184871
# 2010-01-08  0.664833
# 2010-01-11 -0.882147

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3585 entries, 2010-01-05 to 2024-04-03
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    3585 non-null   float64
# dtypes: float64(1)
# memory usage: 56.0 KB

# %%
ret.plot(kind = "hist", figsize = (12 ,8), bins = 100)
plt.show()

# %%
ret[ret.AAPL<=0].shape
# Out:
# (1703, 1)

# %%
daily_mean_Return = ret.mean()
daily_mean_Return
# Out:
# AAPL    0.102184
# dtype: float64

# %%
var_daily_Returns = ret.var()
var_daily_Returns
# Out:
# AAPL    3.133796
# dtype: float64

# %%
std_daily_Returns = np.sqrt(var_daily_Returns)
std_daily_Returns
# Out:
# AAPL    1.770253
# dtype: float64

# %%
# Out:
# 121.00000000000003

# %%
ann_mean_Return = ret.mean() * 252
ann_mean_Return
# Out:
# AAPL    25.750414
# dtype: float64

# %%
ann_var_Returns = ret.var() * 252
ann_var_Returns
# Out:
# AAPL    789.716647
# dtype: float64

# %%
ann_std_Returns = np.sqrt(ann_var_Returns)
ann_std_Returns
# Out:
# AAPL    28.101898
# dtype: float64

# %%
ret.std() * np.sqrt(252)

# %% [markdown]
# ### Financial Time Series - Return and Risk

# %%
import numpy as np

# %%
norm.plot(figsize = (15, 8 ), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %%
close.head()
# Out:
#                  AAPL          BA         DIS         GOOG         IBM  \
# Date
# 2018-12-31  39.435001  322.500000  109.650002  1035.609985  108.671127
# 2019-01-02  39.480000  323.809998  108.970001  1045.849976  110.143402
# 2019-01-03  35.547501  310.899994  106.330002  1016.059998  107.944550
# 2019-01-04  37.064999  327.079987  109.610001  1070.709961  112.160614
# 2019-01-07  36.982498  328.109985  110.559998  1068.390015  112.954109
#
#                    KO        MSFT       TSLA
# Date
# 2018-12-31  47.349998  101.570000  66.559998
# 2019-01-02  46.930000  101.120003  62.023998
# 2019-01-03  46.639999   97.400002  60.071999
# 2019-01-04  47.570000  101.930000  63.537998
# 2019-01-07  46.950001  102.059998  66.991997

# %%
close.pct_change().dropna()
# Out:
#                 AAPL        BA       DIS       IBM        KO      MSFT
# Date
# 2010-01-04  0.015565  0.037872 -0.005581  0.011841  0.000702  0.015420
# 2010-01-05  0.001729  0.032752 -0.002495 -0.012080 -0.012097  0.000323
# 2010-01-06 -0.015906  0.030334 -0.005314 -0.006496 -0.000355 -0.006137
# 2010-01-07 -0.001849  0.040482  0.000314 -0.003462 -0.002485 -0.010400
# 2010-01-08  0.006648 -0.009646  0.001571  0.010035 -0.018509  0.006897
# ...              ...       ...       ...       ...       ...       ...
# 2019-01-30  0.068335  0.062509 -0.006943  0.000372  0.009705  0.033417
# 2019-01-31  0.007201 -0.005416  0.012621  0.000298  0.005641 -0.018330
# 2019-02-01  0.000481  0.004694 -0.001973 -0.002381  0.011843 -0.015800
# 2019-02-04  0.028405  0.024701  0.004492  0.008128  0.011294  0.028799
# 2019-02-05  0.017109  0.033199  0.007692  0.002663  0.000203  0.013997
#
# [2288 rows x 6 columns]

# %%
ret = close.pct_change().dropna()

# %%
ret.head()
# Out:
# Ticker          AAPL        BA       DIS      GOOG       IBM        KO  \
# Date
# 2010-06-30 -0.018113 -0.004600 -0.024768 -0.020495 -0.012871 -0.004173
# 2010-07-01 -0.012126 -0.007809 -0.000317 -0.012271 -0.007370 -0.001796
# 2010-07-02 -0.006198 -0.005140 -0.003493 -0.006690 -0.005793  0.000400
# 2010-07-06  0.006844 -0.009364  0.010835 -0.001100  0.013130  0.007592
# 2010-07-07  0.040381  0.031617  0.044767  0.032403  0.028673  0.020623
#
# Ticker          MSFT      TSLA
# Date
# 2010-06-30 -0.012870 -0.002511
# 2010-07-01  0.006519 -0.078473
# 2010-07-02  0.004750 -0.125683
# 2010-07-06  0.023636 -0.160937
# 2010-07-07  0.020151 -0.019243

# %%
ret.describe().loc[["mean", "std"], :].T
# Out:
#             mean       std
# Ticker
# AAPL    0.000999  0.017616
# BA      0.000569  0.022703
# DIS     0.000513  0.016525
# GOOG    0.000906  0.017208
# IBM     0.000235  0.014120
# KO      0.000309  0.010846
# MSFT    0.000969  0.016320
# TSLA    0.001983  0.035747

# %%
summary = ret.describe().T.loc[:, ["mean", "std"]]
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.000999  0.017616
# BA      0.000569  0.022703
# DIS     0.000513  0.016525
# GOOG    0.000906  0.017208
# IBM     0.000235  0.014120
# KO      0.000309  0.010846
# MSFT    0.000969  0.016320
# TSLA    0.001983  0.035747

# %%
summary["mean"] = summary["mean"]*252
summary["std"] = summary["std"] * np.sqrt(252)

# %%
summary
# Out:
#            mean        std
# AAPL  25.750414  28.101898

# %%
summary.plot(kind = "scatter", x = "std", y = "mean", figsize = (15,12), s = 50, fontsize = 15)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i, "std"]+0.002, summary.loc[i, "mean"]+0.002), size = 15)
plt.xlabel("ann. Risk(std)", fontsize = 15)
plt.ylabel("ann. Return", fontsize = 15)
plt.title("Risk/Return", fontsize = 20)
plt.show()

# %% [markdown]
# ### Financial Time Series - Covariance and Correlation

# %%
ret.head()
# Out:
# Ticker          AAPL        BA       DIS      GOOG       IBM        KO  \
# Date
# 2010-06-30 -0.018113 -0.004600 -0.024768 -0.020495 -0.012871 -0.004173
# 2010-07-01 -0.012126 -0.007809 -0.000317 -0.012271 -0.007370 -0.001796
# 2010-07-02 -0.006198 -0.005140 -0.003493 -0.006690 -0.005793  0.000400
# 2010-07-06  0.006844 -0.009364  0.010835 -0.001100  0.013130  0.007592
# 2010-07-07  0.040381  0.031617  0.044767  0.032403  0.028673  0.020623
#
# Ticker          MSFT      TSLA
# Date
# 2010-06-30 -0.012870 -0.002511
# 2010-07-01  0.006519 -0.078473
# 2010-07-02  0.004750 -0.125683
# 2010-07-06  0.023636 -0.160937
# 2010-07-07  0.020151 -0.019243

# %%
ret.cov()
# Out:
# Ticker      AAPL        BA       DIS      GOOG       IBM        KO      MSFT  \
# Ticker
# AAPL    0.000310  0.000154  0.000117  0.000168  0.000098  0.000065  0.000169
# BA      0.000154  0.000515  0.000188  0.000148  0.000140  0.000101  0.000143
# DIS     0.000117  0.000188  0.000273  0.000126  0.000099  0.000077  0.000124
# GOOG    0.000168  0.000148  0.000126  0.000296  0.000096  0.000065  0.000180
# IBM     0.000098  0.000140  0.000099  0.000096  0.000199  0.000072  0.000105
# KO      0.000065  0.000101  0.000077  0.000065  0.000072  0.000118  0.000072
# MSFT    0.000169  0.000143  0.000124  0.000180  0.000105  0.000072  0.000266
# TSLA    0.000224  0.000225  0.000170  0.000203  0.000103  0.000069  0.000203
#
# Ticker      TSLA
# Ticker
# AAPL    0.000224
# BA      0.000225
# DIS     0.000170
# GOOG    0.000203
# IBM     0.000103
# KO      0.000069
# MSFT    0.000203
# TSLA    0.001278

# %%
ret.corr()
# Out:
# Ticker      AAPL        BA       DIS      GOOG       IBM        KO      MSFT  \
# Ticker
# AAPL    1.000000  0.384232  0.402624  0.555532  0.392900  0.341556  0.588300
# BA      0.384232  1.000000  0.500531  0.379202  0.435317  0.411673  0.385476
# DIS     0.402624  0.500531  1.000000  0.444590  0.424031  0.429913  0.458558
# GOOG    0.555532  0.379202  0.444590  1.000000  0.394806  0.350486  0.640567
# IBM     0.392900  0.435317  0.424031  0.394806  1.000000  0.467175  0.455119
# KO      0.341556  0.411673  0.429913  0.350486  0.467175  1.000000  0.404162
# MSFT    0.588300  0.385476  0.458558  0.640567  0.455119  0.404162  1.000000
# TSLA    0.356450  0.277627  0.287630  0.329308  0.204392  0.178745  0.348431
#
# Ticker      TSLA
# Ticker
# AAPL    0.356450
# BA      0.277627
# DIS     0.287630
# GOOG    0.329308
# IBM     0.204392
# KO      0.178745
# MSFT    0.348431
# TSLA    1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(), cmap = "Reds", annot = True, annot_kws={"size":15}, vmax = 0.6)
plt.show()

# %% [markdown]
# ### Helpful DatetimeIndex Attributes and Methods

# %%
import pandas as pd

# %%
stocks = pd.read_csv("stocks.csv", header = [0,1], index_col= [0], parse_dates= [0])

# %%
stocks.head()

# %%
close = stocks.loc[:, "Close"].copy()

# %%
close.head()

# %%
close.info()

# %%
close.index

# %%
close.index.day

# %%
close.index.month

# %%
close.index.year

# %%
close.index.day_name()

# %%
close.index.month_name()

# %%
close.index.weekday

# %%
close.index.quarter

# %%
close.index.days_in_month

# %%
close.index.week

# %%
close.index.weekofyear

# %%
close.index.is_month_end

# %%
close["Day"] = stocks.index.day_name()
close["Quarter"] = stocks.index.quarter

# %%
close.head()

# %% [markdown]
# ### Filling NA Values with bfill, ffill and interpolation

# %%
close.head()

# %%
close.tail()

# %%
all_days = pd.date_range(start = "2009-12-31", end = "2019-02-06", freq = "D")
all_days

# %%
close = close.reindex(all_days)

# %%
close.head(20)

# %%
close.Day = close.index.day_name()
close.Quarter = close.index.quarter

# %%
close.fillna(method = "ffill", inplace= True)

# %%
close.head(15)

# %%
temp = pd.read_csv("temp.csv", parse_dates=["datetime"], index_col = "datetime")

# %%
temp.head(10)

# %%
temp = temp.resample("30 Min").mean()
temp.head(10)

# %%
temp.interpolate()
